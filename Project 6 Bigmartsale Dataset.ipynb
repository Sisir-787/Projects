# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import zscore

# %% [markdown]
# Problem Statement:
#
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store.
#
# Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing the sales of their products.
#
# The dataset includes two files:
#
# - bigdatamart_Train.csv: Use this file for the model building purpose.
#
# - bigdatamart_Test.csv: Use this file for getting predictions from the trained model.

# %%
df=pd.read_csv('bigdatamart_Train.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df_test=pd.read_csv('bigdatamart_Test.csv')
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df.shape
# Out:
# (8523, 12)

# %%
df_test.shape
# Out:
# (5681, 11)

# %%
len(df['Item_Identifier'].unique())
# Out:
# 1559

# %%
len(df_test['Item_Identifier'].unique())
# Out:
# 1543

# %%
df.isnull().sum() # checking the null values
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum() # checking the null values
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is null values in item_weight and outlate size.
# The item_weight is float type data so its null value will be replaced by mean and outlate_type is string object so its null value will be replaced by mode value

# %%
sns.heatmap(df_test.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# Test dataset also has the null values

# %%
#cheching the categorical values
obj_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        obj_col.append(i)

obj_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %% [markdown]
# We dont require the Item Identifier and the outlet Indetifier , so we will remove it

# %%
obj_col.remove('Item_Identifier')
obj_col.remove('Outlet_Identifier')

# %%
#checking the unique columns in object cols
for i in obj_col:
    print(i)
    print(df[i].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# We can observe 'Item_Fat_Content' has similar column name
#      (i) Regular abd reg
#     (ii) Low Fat and LF
#     (iii) low fat and Low Fat
# we can merge the both of them respectively

# %%
#cheching the categorical values
obj_col=[]
for i in df_test.dtypes.index:
    if df_test.dtypes[i]=='object':
        obj_col.append(i)

obj_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
obj_col.remove('Item_Identifier')
obj_col.remove('Outlet_Identifier')

# %%
#checking the unique columns in object cols
for i in obj_col:
    print(i)
    print(df_test[i].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Medium    1862
# Small     1592
# High       621
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    2233
# Tier 2    1856
# Tier 1    1592
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    3717
# Grocery Store         722
# Supermarket Type3     624
# Supermarket Type2     618
# Name: Outlet_Type, dtype: int64

# %%
# fill the missing values
item_weight_mean = df.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %% [markdown]
# Found different weight mean for different Item_itedifier

# %%
miss_bool = df['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
#missing_bool.value_counts()

# %%
for i, item in enumerate(df['Item_Identifier']):
    if miss_bool[i]:
        if item in item_weight_mean:
            df['Item_Weight'][i] = item_weight_mean.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i] = np.mean(df['Item_Weight'])

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
# fill the missing values
item_weight_mean2 = df_test.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
item_weight_mean2
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1527 rows x 1 columns]

# %%
miss_bool2 = df_test['Item_Weight'].isnull()
miss_bool2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Name: Item_Weight, Length: 5681, dtype: bool

# %% [markdown]
# Replace all null values in Item_Weight with mean

# %%
len(df_test['Item_Weight'])
# Out:
# 5681

# %%
for i, item in enumerate(df_test['Item_Identifier']):
    if miss_bool2[i]:
        if item in item_weight_mean:
            df_test['Item_Weight'][i] = item_weight_mean2.loc[item]['Item_Weight']
        else:
            df_test['Item_Weight'][i] = np.mean(df_test['Item_Weight'])

# %%
outlate_size_mode=df.pivot_table(values='Outlet_Size',columns='Outlet_Type',aggfunc=(lambda x: x.mode()))
outlate_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
def fill_outletsize(cols):
    o_size=cols[0]
    o_type=cols[1]
    if pd.isnull(o_size):
        if o_type=='Grocery Store':
            return 'Small'
        elif o_type=='Supermarket Type1':
            return 'Small'
        elif o_type=='Supermarket Type2':
            return 'Medium'
        elif o_type=='Supermarket Type3':
            return 'Medium'
    else:
        return o_size

# %%
df['Outlet_Size']=df[['Outlet_Size','Outlet_Type']].apply(fill_outletsize,axis=1)

# %%
outlate_size_mode=df_test.pivot_table(values='Outlet_Size',columns='Outlet_Type',aggfunc=(lambda x: x.mode()))
outlate_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
df_test['Outlet_Size']=df_test[['Outlet_Size','Outlet_Type']].apply(fill_outletsize,axis=1)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# using the describe functino we can find the Item_Visibilty has the Zero values

# %%
df_test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  5681.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.245189         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       9.195000         0.027047    94.412000                1987.000000
# 50%      12.695633         0.054154   141.415400                1999.000000
# 75%      15.850000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
sum(df['Item_Visibility']==0)
# Out:
# 526

# %%
sum(df_test['Item_Visibility']==0)
# Out:
# 353

# %% [markdown]
# 526 values are 0

# %%
#replacig the item_visibity '0' vaulues with mean
mean_visibility = df['Item_Visibility'].mean(skipna=True)

df['Item_Visibility']=df.Item_Visibility.mask(df.Item_Visibility == 0,mean_visibility)
sum(df['Item_Visibility']==0)
# Out:
# 0

# %%
#replacig the item_visibity '0' vaulues with mean
mean_visibility = df_test['Item_Visibility'].mean(skipna=True)

df_test['Item_Visibility']=df_test.Item_Visibility.mask(df_test.Item_Visibility == 0,mean_visibility)
sum(df_test['Item_Visibility']==0)
# Out:
# 0

# %% [markdown]
# Replaced the 0 values with mean

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat','Rgular':'Regular'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df_test['Item_Fat_Content']=df_test['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat','Rgular':'Regular'})
df_test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %%
df['New_Item_Type'] = df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_Type']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
df_test['New_Item_Type'] = df_test['Item_Identifier'].apply(lambda x: x[:2])
df_test['New_Item_Type']
# Out:
# 0       FD
# 1       FD
# 2       NC
# 3       FD
# 4       FD
#         ..
# 5676    FD
# 5677    FD
# 5678    NC
# 5679    FD
# 5680    FD
# Name: New_Item_Type, Length: 5681, dtype: object

# %%
df['New_Item_Type'] = df['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
df['New_Item_Type'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Type, dtype: int64

# %%
df.loc[df['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
df_test['New_Item_Type'] = df_test['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
df_test['New_Item_Type'].value_counts()
# Out:
# Food              4076
# Non-Consumable    1087
# Drinks             518
# Name: New_Item_Type, dtype: int64

# %%
df_test.loc[df_test['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
df_test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       2581
# Regular       2013
# Non-Edible    1087
# Name: Item_Fat_Content, dtype: int64

# %%
# create small values for establishment year
df['Outlet_Years'] = 2013 - df['Outlet_Establishment_Year']

# %%
# create small values for establishment year
df_test['Outlet_Years'] = 2013 - df_test['Outlet_Establishment_Year']

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type  Outlet_Years
# 0  Supermarket Type1          3735.1380            Food            14
# 1  Supermarket Type2           443.4228          Drinks             4
# 2  Supermarket Type1          2097.2700            Food            14
# 3      Grocery Store           732.3800            Food            15
# 4  Supermarket Type1           994.7052  Non-Consumable            26

# %% [markdown]
# Using the sources I decoded that the item prefix letters in Item_Identifier
# (i) FD represent FOOD
# (ii) DR represent Drink
# (iii) NC represent Non Consumable

# %%
df['Item_Code']=df['Item_Identifier'].apply(lambda x: x[:2])
df['Item_Code'].head(10)
# Out:
# 0    FD
# 1    DR
# 2    FD
# 3    FD
# 4    NC
# 5    FD
# 6    FD
# 7    FD
# 8    FD
# 9    FD
# Name: Item_Code, dtype: object

# %%
df['Item_Identifier']=df['Item_Identifier'].apply(lambda x: x[:2])
df['Item_Identifier']=df['Item_Identifier'].replace({'FD':'Food','DR':'Drink','NC':'Non Consumable'})
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            Food         9.30          Low Fat         0.016047
# 1           Drink         5.92          Regular         0.019278
# 2            Food        17.50          Low Fat         0.016760
# 3            Food        19.20          Regular         0.066132
# 4  Non Consumable         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type  Outlet_Years  \
# 0  Supermarket Type1          3735.1380            Food            14
# 1  Supermarket Type2           443.4228          Drinks             4
# 2  Supermarket Type1          2097.2700            Food            14
# 3      Grocery Store           732.3800            Food            15
# 4  Supermarket Type1           994.7052  Non-Consumable            26
#
#   Item_Code
# 0        FD
# 1        DR
# 2        FD
# 3        FD
# 4        NC

# %%
df_test['Item_Code']=df_test['Item_Identifier'].apply(lambda x: x[:2])
df_test['Item_Code'].head(10)
# Out:
# 0    FD
# 1    FD
# 2    NC
# 3    FD
# 4    FD
# 5    FD
# 6    FD
# 7    FD
# 8    FD
# 9    FD
# Name: Item_Code, dtype: object

# %% [markdown]
# Strip the Item Identifier for first two digit and encoded for
# (i) FD as Food
# (ii) DR as Drink
# (iii) NC as Non Consumable

# %%
df_test['Item_Identifier']=df_test['Item_Identifier'].apply(lambda x: x[:2])
df_test['Item_Identifier']=df_test['Item_Identifier'].replace({'FD':'Food','DR':'Drink','NC':'Non Consumable'})
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0            Food    20.750000          Low Fat         0.007565  Snack Foods
# 1            Food     8.300000          Regular         0.038428        Dairy
# 2  Non Consumable    14.600000       Non-Edible         0.099575       Others
# 3            Food     7.315000          Low Fat         0.015388  Snack Foods
# 4            Food    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007       Small
# 2  241.7538            OUT010                       1998       Small
# 3  155.0340            OUT017                       2007       Small
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type   New_Item_Type  Outlet_Years  \
# 0               Tier 1  Supermarket Type1            Food            14
# 1               Tier 2  Supermarket Type1            Food             6
# 2               Tier 3      Grocery Store  Non-Consumable            15
# 3               Tier 2  Supermarket Type1            Food             6
# 4               Tier 3  Supermarket Type3            Food            28
#
#   Item_Code
# 0        FD
# 1        FD
# 2        NC
# 3        FD
# 4        FD

# %%
df.drop('Item_Code',axis=1,inplace=True)

# %%
df_test.drop('Item_Code',axis=1,inplace=True)

# %%
df['Item_Identifier'].value_counts()
# Out:
# Food              6125
# Non Consumable    1599
# Drink              799
# Name: Item_Identifier, dtype: int64

# %%
df_test['Item_Identifier'].value_counts()
# Out:
# Food              4076
# Non Consumable    1087
# Drink              518
# Name: Item_Identifier, dtype: int64

# %%
df['Outlet_Establishment_Year']=df['Outlet_Establishment_Year']-2013
df['Outlet_Establishment_Year']
# Out:
# 0      -14
# 1       -4
# 2      -14
# 3      -15
# 4      -26
#         ..
# 8518   -26
# 8519   -11
# 8520    -9
# 8521    -4
# 8522   -16
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64

# %%
df_test['Outlet_Establishment_Year']=df_test['Outlet_Establishment_Year']-2013
df_test['Outlet_Establishment_Year']
# Out:
# 0      -14
# 1       -6
# 2      -15
# 3       -6
# 4      -28
#         ..
# 5676   -16
# 5677    -4
# 5678   -11
# 5679    -6
# 5680   -11
# Name: Outlet_Establishment_Year, Length: 5681, dtype: int64

# %%
sns.countplot(x='Item_Fat_Content',hue='Item_Identifier',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# low fat content data is more eatable , re

# %%
sns.set_style('whitegrid')
sns.countplot(x='Item_Identifier',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='count'>

# %% [markdown]
# Food item are much more than Drink and Non-Consumables

# %%
sns.countplot(x='Item_Fat_Content',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# Low fat item are more than Regulat fat item

# %%
sns.set(rc = {'figure.figsize':(15,5)})

chart=sns.countplot(x='Item_Type',data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %% [markdown]
# Fruits and Vegetables , Snack Foods are more in store

# %%
sns.countplot(x='Outlet_Type',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %% [markdown]
# Supermaket Type1 is much more than the others Outlet Type

# %%
sns.countplot(x='Outlet_Identifier',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %% [markdown]
# Outlet010 and Outlet019 alre less in numbers

# %%
sns.countplot(x='Outlet_Size',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %% [markdown]
# Small outlet are more in numbers

# %%
sns.countplot(x='Outlet_Location_Type',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.distplot(df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %% [markdown]
# Outlets in Tier3 are more than Tier 2 and Tier 1

# %%
chart=sns.barplot(x='Item_Type',y='Item_Visibility',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %% [markdown]
# Item Visibilty of all the item type is almost same

# %%
chart=sns.barplot(x='Item_Type',y='Item_MRP',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %%
chart=sns.barplot(x='Outlet_Type',y='Outlet_Establishment_Year',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Supermarket Type1'),
#  Text(1, 0, 'Supermarket Type2'),
#  Text(2, 0, 'Grocery Store'),
#  Text(3, 0, 'Supermarket Type3')]

# %% [markdown]
# Supermarket Type3 stores are oldest store whereas Supermarket2 are newest

# %%
chart=sns.barplot(x='Item_Type',y='Item_Outlet_Sales',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %% [markdown]
# sales of all the items are alomost same

# %%
chart=sns.barplot(x='Item_Type',y='Item_Outlet_Sales',hue='Outlet_Size',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %% [markdown]
# Medium size outlet has more sales compare to small and high

# %%
chart=sns.barplot(x='Item_Type',y='Item_Outlet_Sales',hue='Outlet_Type',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %% [markdown]
# (i) In almost all type of Supermarket Type3 all the items sales are high
# (ii) Seafood is sales is more in Supermarket Type2
# (iii) In Grocery store all the items sales are much less , need to improvise

# %%
chart=sns.countplot(x='Outlet_Location_Type',hue='Outlet_Type',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Tier 1'), Text(1, 0, 'Tier 3'), Text(2, 0, 'Tier 2')]

# %% [markdown]
# (i) There is Supermarket Type 2 and Type 3 in Tier 1
# (ii) Supermarket Type 2, type 3 and Grocery is not available in Tier 2

# %%
chart=sns.barplot(x='Item_Outlet_Sales',y='Outlet_Location_Type',data=df)

# %% [markdown]
# Tier 2 outlet has more sales, Tier 1 outlet has less sales need to improve

# %%
chart=sns.barplot(x='Outlet_Type',y='Item_Outlet_Sales',hue='Outlet_Type',data=df)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Supermarket Type1'),
#  Text(1, 0, 'Supermarket Type2'),
#  Text(2, 0, 'Grocery Store'),
#  Text(3, 0, 'Supermarket Type3')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  New_Item_Type              8523 non-null   object
#  13  Outlet_Years               8523 non-null   int64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 932.3+ KB

# %%
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %% [markdown]
# # Feature Engineering

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility              1.286877
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# Outlet_Years                 0.396641
# dtype: float64

# %% [markdown]
# There is skewness in Item_Visibility

# %%
df['Item_Visibility']=np.sqrt(df['Item_Visibility'])

# %% [markdown]
# Removed the skewness using sqrt methon

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility              0.405969
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# Outlet_Years                 0.396641
# dtype: float64

# %%
df_test.skew()
# Out:
# Item_Weight                  0.142813
# Item_Visibility              1.372659
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# Outlet_Years                 0.396306
# dtype: float64

# %%
df_test['Item_Visibility']=np.sqrt(df_test['Item_Visibility'])

# %%
df_test.skew()
# Out:
# Item_Weight                  0.142813
# Item_Visibility              0.435375
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# Outlet_Years                 0.396306
# dtype: float64

# %%
columns=['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']

# %%
for i in columns:
    sns.distplot(df[i])
    plt.show()

# %%
for i in columns:
    sns.distplot(df_test[i])
    plt.show()

# %%
for i in columns:
    sns.boxplot(df[i])
    plt.show()

# %%
for i in columns:
    sns.boxplot(df_test[i])
    plt.show()

# %%
Object=['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in Object:
    df[i]=le.fit_transform(df[i])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in Object:
    df_test[i]=le.fit_transform(df_test[i])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0            Food         9.30                 0         0.126678          4
# 1           Drink         5.92                 2         0.138846         14
# 2            Food        17.50                 0         0.129461         10
# 3            Food        19.20                 2         0.257161          6
# 4  Non Consumable         8.93                 1         0.257161          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                        -14            1
# 1   48.2692            OUT018                         -4            1
# 2  141.6180            OUT049                        -14            1
# 3  182.0950            OUT010                        -15            2
# 4   53.8614            OUT013                        -26            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type  \
# 0                     0            1          3735.1380              1
# 1                     2            2           443.4228              0
# 2                     0            1          2097.2700              1
# 3                     2            0           732.3800              1
# 4                     2            1           994.7052              2
#
#    Outlet_Years
# 0            14
# 1             4
# 2            14
# 3            15
# 4            26

# %%
df=pd.get_dummies(df,columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'])
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food         9.30         0.126678          4  249.8092
# 1           Drink         5.92         0.138846         14   48.2692
# 2            Food        17.50         0.129461         10  141.6180
# 3            Food        19.20         0.257161          6  182.0950
# 4  Non Consumable         8.93         0.257161          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                        -14          3735.1380
# 1            OUT018                         -4           443.4228
# 2            OUT049                        -14          2097.2700
# 3            OUT010                        -15           732.3800
# 4            OUT013                        -26           994.7052
#
#    Outlet_Years  Item_Fat_Content_0  ...  Outlet_Location_Type_0  \
# 0            14                   1  ...                       1
# 1             4                   0  ...                       0
# 2            14                   1  ...                       1
# 3            15                   0  ...                       0
# 4            26                   0  ...                       0
#
#    Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# 0                       0                       0              0
# 1                       0                       1              0
# 2                       0                       0              0
# 3                       0                       1              1
# 4                       0                       1              0
#
#    Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# 0              1              0              0                0
# 1              0              1              0                1
# 2              1              0              0                0
# 3              0              0              0                0
# 4              1              0              0                0
#
#    New_Item_Type_1  New_Item_Type_2
# 0                1                0
# 1                0                0
# 2                1                0
# 3                1                0
# 4                0                1
#
# [5 rows x 25 columns]

# %%
df_test=pd.get_dummies(df_test,columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'])
df_test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food    20.750000         0.086976         13  107.8622
# 1            Food     8.300000         0.196030          4   87.3198
# 2  Non Consumable    14.600000         0.315555         11  241.7538
# 3            Food     7.315000         0.124050         13  155.0340
# 4            Food    12.695633         0.344383          4  234.2300
#
#   Outlet_Identifier  Outlet_Establishment_Year  Outlet_Years  \
# 0            OUT049                        -14            14
# 1            OUT017                         -6             6
# 2            OUT010                        -15            15
# 3            OUT017                         -6             6
# 4            OUT027                        -28            28
#
#    Item_Fat_Content_0  Item_Fat_Content_1  ...  Outlet_Location_Type_0  \
# 0                   1                   0  ...                       1
# 1                   0                   0  ...                       0
# 2                   0                   1  ...                       0
# 3                   1                   0  ...                       0
# 4                   0                   0  ...                       0
#
#    Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# 0                       0                       0              0
# 1                       1                       0              0
# 2                       0                       1              1
# 3                       1                       0              0
# 4                       0                       1              0
#
#    Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# 0              1              0              0                0
# 1              1              0              0                0
# 2              0              0              0                0
# 3              1              0              0                0
# 4              0              0              1                0
#
#    New_Item_Type_1  New_Item_Type_2
# 0                1                0
# 1                1                0
# 2                0                1
# 3                1                0
# 4                1                0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility    Item_Type     Item_MRP  \
# count  8523.000000      8523.000000  8523.000000  8523.000000
# mean     12.857645         0.249580     7.226681   140.992782
# std       4.226124         0.089018     4.209990    62.275067
# min       4.555000         0.059789     0.000000    31.290000
# 25%       9.310000         0.181894     4.000000    93.826500
# 50%      12.857645         0.250033     6.000000   143.012800
# 75%      16.000000         0.307547    10.000000   185.643700
# max      21.350000         0.573054    15.000000   266.888400
#
#        Outlet_Establishment_Year  Item_Outlet_Sales  Outlet_Years  \
# count                8523.000000        8523.000000   8523.000000
# mean                  -15.168133        2181.288914     15.168133
# std                     8.371760        1706.499616      8.371760
# min                   -28.000000          33.290000      4.000000
# 25%                   -26.000000         834.247400      9.000000
# 50%                   -14.000000        1794.331000     14.000000
# 75%                    -9.000000        3101.296400     26.000000
# max                    -4.000000       13086.964800     28.000000
#
#        Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  ...  \
# count         8523.000000         8523.000000         8523.000000  ...
# mean             0.459697            0.187610            0.352693  ...
# std              0.498402            0.390423            0.477836  ...
# min              0.000000            0.000000            0.000000  ...
# 25%              0.000000            0.000000            0.000000  ...
# 50%              0.000000            0.000000            0.000000  ...
# 75%              1.000000            0.000000            1.000000  ...
# max              1.000000            1.000000            1.000000  ...
#
#        Outlet_Location_Type_0  Outlet_Location_Type_1  Outlet_Location_Type_2  \
# count             8523.000000             8523.000000             8523.000000
# mean                 0.280183                0.326763                0.393054
# std                  0.449115                0.469057                0.488457
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  1.000000                1.000000                1.000000
# max                  1.000000                1.000000                1.000000
#
#        Outlet_Type_0  Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  \
# count    8523.000000    8523.000000    8523.000000    8523.000000
# mean        0.127068       0.654347       0.108882       0.109703
# std         0.333069       0.475609       0.311509       0.312538
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       1.000000       0.000000       0.000000
# 75%         0.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        New_Item_Type_0  New_Item_Type_1  New_Item_Type_2
# count      8523.000000      8523.000000      8523.000000
# mean          0.093746         0.718644         0.187610
# std           0.291493         0.449687         0.390423
# min           0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         1.000000         0.000000
# 75%           0.000000         1.000000         0.000000
# max           1.000000         1.000000         1.000000
#
# [8 rows x 23 columns]

# %%
df_test.describe()
# Out:
#        Item_Weight  Item_Visibility    Item_Type     Item_MRP  \
# count  5681.000000      5681.000000  5681.000000  5681.000000
# mean     12.695633         0.249002     7.233410   141.023273
# std       4.245189         0.088117     4.219057    61.809091
# min       4.555000         0.059928     0.000000    31.990000
# 25%       9.195000         0.182230     4.000000    94.412000
# 50%      12.695633         0.249273     6.000000   141.415400
# 75%      15.850000         0.305717    10.000000   186.026600
# max      21.350000         0.568891    15.000000   266.588400
#
#        Outlet_Establishment_Year  Outlet_Years  Item_Fat_Content_0  \
# count                5681.000000   5681.000000         5681.000000
# mean                  -15.171097     15.171097            0.454321
# std                     8.372256      8.372256            0.497953
# min                   -28.000000      4.000000            0.000000
# 25%                   -26.000000      9.000000            0.000000
# 50%                   -14.000000     14.000000            0.000000
# 75%                    -9.000000     26.000000            1.000000
# max                    -4.000000     28.000000            1.000000
#
#        Item_Fat_Content_1  Item_Fat_Content_2  Outlet_Size_0  ...  \
# count          5681.00000         5681.000000    5681.000000  ...
# mean              0.19134            0.354339       0.109312  ...
# std               0.39339            0.478355       0.312057  ...
# min               0.00000            0.000000       0.000000  ...
# 25%               0.00000            0.000000       0.000000  ...
# 50%               0.00000            0.000000       0.000000  ...
# 75%               0.00000            1.000000       0.000000  ...
# max               1.00000            1.000000       1.000000  ...
#
#        Outlet_Location_Type_0  Outlet_Location_Type_1  Outlet_Location_Type_2  \
# count             5681.000000             5681.000000             5681.000000
# mean                 0.280232                0.326703                0.393065
# std                  0.449152                0.469049                0.488474
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  1.000000                1.000000                1.000000
# max                  1.000000                1.000000                1.000000
#
#        Outlet_Type_0  Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  \
# count    5681.000000    5681.000000    5681.000000    5681.000000
# mean        0.127090       0.654286       0.108784       0.109840
# std         0.333103       0.475642       0.311395       0.312718
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       1.000000       0.000000       0.000000
# 75%         0.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        New_Item_Type_0  New_Item_Type_1  New_Item_Type_2
# count      5681.000000      5681.000000       5681.00000
# mean          0.091181         0.717479          0.19134
# std           0.287892         0.450265          0.39339
# min           0.000000         0.000000          0.00000
# 25%           0.000000         0.000000          0.00000
# 50%           0.000000         1.000000          0.00000
# 75%           0.000000         1.000000          0.00000
# max           1.000000         1.000000          1.00000
#
# [8 rows x 22 columns]

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food         9.30         0.126678          4  249.8092
# 1           Drink         5.92         0.138846         14   48.2692
# 2            Food        17.50         0.129461         10  141.6180
# 3            Food        19.20         0.257161          6  182.0950
# 4  Non Consumable         8.93         0.257161          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                        -14          3735.1380
# 1            OUT018                         -4           443.4228
# 2            OUT049                        -14          2097.2700
# 3            OUT010                        -15           732.3800
# 4            OUT013                        -26           994.7052
#
#    Outlet_Years  Item_Fat_Content_0  ...  Outlet_Location_Type_0  \
# 0            14                   1  ...                       1
# 1             4                   0  ...                       0
# 2            14                   1  ...                       1
# 3            15                   0  ...                       0
# 4            26                   0  ...                       0
#
#    Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# 0                       0                       0              0
# 1                       0                       1              0
# 2                       0                       0              0
# 3                       0                       1              1
# 4                       0                       1              0
#
#    Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# 0              1              0              0                0
# 1              0              1              0                1
# 2              1              0              0                0
# 3              0              0              0                0
# 4              1              0              0                0
#
#    New_Item_Type_1  New_Item_Type_2
# 0                1                0
# 1                0                0
# 2                1                0
# 3                1                0
# 4                0                1
#
# [5 rows x 25 columns]

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food    20.750000         0.086976         13  107.8622
# 1            Food     8.300000         0.196030          4   87.3198
# 2  Non Consumable    14.600000         0.315555         11  241.7538
# 3            Food     7.315000         0.124050         13  155.0340
# 4            Food    12.695633         0.344383          4  234.2300
#
#   Outlet_Identifier  Outlet_Establishment_Year  Outlet_Years  \
# 0            OUT049                        -14            14
# 1            OUT017                         -6             6
# 2            OUT010                        -15            15
# 3            OUT017                         -6             6
# 4            OUT027                        -28            28
#
#    Item_Fat_Content_0  Item_Fat_Content_1  ...  Outlet_Location_Type_0  \
# 0                   1                   0  ...                       1
# 1                   0                   0  ...                       0
# 2                   0                   1  ...                       0
# 3                   1                   0  ...                       0
# 4                   0                   0  ...                       0
#
#    Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# 0                       0                       0              0
# 1                       1                       0              0
# 2                       0                       1              1
# 3                       1                       0              0
# 4                       0                       1              0
#
#    Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# 0              1              0              0                0
# 1              1              0              0                0
# 2              0              0              0                0
# 3              1              0              0                0
# 4              0              0              1                0
#
#    New_Item_Type_1  New_Item_Type_2
# 0                1                0
# 1                1                0
# 2                0                1
# 3                1                0
# 4                1                0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   int32
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Item_Outlet_Sales          8523 non-null   float64
#  8   Outlet_Years               8523 non-null   int64
#  9   Item_Fat_Content_0         8523 non-null   uint8
#  10  Item_Fat_Content_1         8523 non-null   uint8
#  11  Item_Fat_Content_2         8523 non-null   uint8
#  12  Outlet_Size_0              8523 non-null   uint8
#  13  Outlet_Size_1              8523 non-null   uint8
#  14  Outlet_Size_2              8523 non-null   uint8
#  15  Outlet_Location_Type_0     8523 non-null   uint8
#  16  Outlet_Location_Type_1     8523 non-null   uint8
#  17  Outlet_Location_Type_2     8523 non-null   uint8
#  18  Outlet_Type_0              8523 non-null   uint8
#  19  Outlet_Type_1              8523 non-null   uint8
#  20  Outlet_Type_2              8523 non-null   uint8
#  21  Outlet_Type_3              8523 non-null   uint8
#  22  New_Item_Type_0            8523 non-null   uint8
#  23  New_Item_Type_1            8523 non-null   uint8
#  24  New_Item_Type_2            8523 non-null   uint8
# dtypes: float64(4), int32(1), int64(2), object(2), uint8(16)
# memory usage: 699.3+ KB

# %% [markdown]
# # Correlation Matrix

# %%
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is positive correlation between Item_MRP and Item_Outlet_Sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   int32
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Item_Outlet_Sales          8523 non-null   float64
#  8   Outlet_Years               8523 non-null   int64
#  9   Item_Fat_Content_0         8523 non-null   uint8
#  10  Item_Fat_Content_1         8523 non-null   uint8
#  11  Item_Fat_Content_2         8523 non-null   uint8
#  12  Outlet_Size_0              8523 non-null   uint8
#  13  Outlet_Size_1              8523 non-null   uint8
#  14  Outlet_Size_2              8523 non-null   uint8
#  15  Outlet_Location_Type_0     8523 non-null   uint8
#  16  Outlet_Location_Type_1     8523 non-null   uint8
#  17  Outlet_Location_Type_2     8523 non-null   uint8
#  18  Outlet_Type_0              8523 non-null   uint8
#  19  Outlet_Type_1              8523 non-null   uint8
#  20  Outlet_Type_2              8523 non-null   uint8
#  21  Outlet_Type_3              8523 non-null   uint8
#  22  New_Item_Type_0            8523 non-null   uint8
#  23  New_Item_Type_1            8523 non-null   uint8
#  24  New_Item_Type_2            8523 non-null   uint8
# dtypes: float64(4), int32(1), int64(2), object(2), uint8(16)
# memory usage: 699.3+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food         9.30         0.126678          4  249.8092
# 1           Drink         5.92         0.138846         14   48.2692
# 2            Food        17.50         0.129461         10  141.6180
# 3            Food        19.20         0.257161          6  182.0950
# 4  Non Consumable         8.93         0.257161          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                        -14          3735.1380
# 1            OUT018                         -4           443.4228
# 2            OUT049                        -14          2097.2700
# 3            OUT010                        -15           732.3800
# 4            OUT013                        -26           994.7052
#
#    Outlet_Years  Item_Fat_Content_0  ...  Outlet_Location_Type_0  \
# 0            14                   1  ...                       1
# 1             4                   0  ...                       0
# 2            14                   1  ...                       1
# 3            15                   0  ...                       0
# 4            26                   0  ...                       0
#
#    Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# 0                       0                       0              0
# 1                       0                       1              0
# 2                       0                       0              0
# 3                       0                       1              1
# 4                       0                       1              0
#
#    Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# 0              1              0              0                0
# 1              0              1              0                1
# 2              1              0              0                0
# 3              0              0              0                0
# 4              1              0              0                0
#
#    New_Item_Type_1  New_Item_Type_2
# 0                1                0
# 1                0                0
# 2                1                0
# 3                1                0
# 4                0                1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Train - Test Split

# %%
x = df.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales'])
y = df['Item_Outlet_Sales']

# %%
x.describe()
# Out:
#        Item_Weight  Item_Visibility    Item_Type     Item_MRP  Outlet_Years  \
# count  8523.000000      8523.000000  8523.000000  8523.000000   8523.000000
# mean     12.857645         0.249580     7.226681   140.992782     15.168133
# std       4.226124         0.089018     4.209990    62.275067      8.371760
# min       4.555000         0.059789     0.000000    31.290000      4.000000
# 25%       9.310000         0.181894     4.000000    93.826500      9.000000
# 50%      12.857645         0.250033     6.000000   143.012800     14.000000
# 75%      16.000000         0.307547    10.000000   185.643700     26.000000
# max      21.350000         0.573054    15.000000   266.888400     28.000000
#
#        Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  \
# count         8523.000000         8523.000000         8523.000000
# mean             0.459697            0.187610            0.352693
# std              0.498402            0.390423            0.477836
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              1.000000            0.000000            1.000000
# max              1.000000            1.000000            1.000000
#
#        Outlet_Size_0  Outlet_Size_1  ...  Outlet_Location_Type_0  \
# count    8523.000000    8523.000000  ...             8523.000000
# mean        0.109351       0.327702  ...                0.280183
# std         0.312098       0.469403  ...                0.449115
# min         0.000000       0.000000  ...                0.000000
# 25%         0.000000       0.000000  ...                0.000000
# 50%         0.000000       0.000000  ...                0.000000
# 75%         0.000000       1.000000  ...                1.000000
# max         1.000000       1.000000  ...                1.000000
#
#        Outlet_Location_Type_1  Outlet_Location_Type_2  Outlet_Type_0  \
# count             8523.000000             8523.000000    8523.000000
# mean                 0.326763                0.393054       0.127068
# std                  0.469057                0.488457       0.333069
# min                  0.000000                0.000000       0.000000
# 25%                  0.000000                0.000000       0.000000
# 50%                  0.000000                0.000000       0.000000
# 75%                  1.000000                1.000000       0.000000
# max                  1.000000                1.000000       1.000000
#
#        Outlet_Type_1  Outlet_Type_2  Outlet_Type_3  New_Item_Type_0  \
# count    8523.000000    8523.000000    8523.000000      8523.000000
# mean        0.654347       0.108882       0.109703         0.093746
# std         0.475609       0.311509       0.312538         0.291493
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       0.000000       0.000000         0.000000
# 50%         1.000000       0.000000       0.000000         0.000000
# 75%         1.000000       0.000000       0.000000         0.000000
# max         1.000000       1.000000       1.000000         1.000000
#
#        New_Item_Type_1  New_Item_Type_2
# count      8523.000000      8523.000000
# mean          0.718644         0.187610
# std           0.449687         0.390423
# min           0.000000         0.000000
# 25%           0.000000         0.000000
# 50%           1.000000         0.000000
# 75%           1.000000         0.000000
# max           1.000000         1.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is: {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is: 0.56270958074306
# At random state 0,the testing accuracy is: 0.5635567895120372
#
#
# At random state 1,the training accuracy is: 0.5632185744821416
# At random state 1,the testing accuracy is: 0.56038553789608
#
#
# At random state 2,the training accuracy is: 0.5672253907350191
# At random state 2,the testing accuracy is: 0.5455842149944208
#
#
# At random state 3,the training accuracy is: 0.554168427664973
# At random state 3,the testing accuracy is: 0.5965912648787519
#
#
# At random state 4,the training accuracy is: 0.5654849477824375
# At random state 4,the testing accuracy is: 0.5505321195378361
#
#
# At random state 5,the training accuracy is: 0.5654693413710521
# At random state 5,the testing accuracy is: 0.5521602452076091
#
#
# At random state 6,the training accuracy is: 0.5666803561116149
# At random state 6,the testing accuracy is: 0.5467451451892016
#
#
# At random state 7,the training accuracy is: 0.5676868817650975
# At random state 7,the testing accuracy is: 0.544944533292487
#
#
# At random state 8,the training accuracy is: 0.5623954637883521
# At random state 8,the testing accuracy is: 0.56366718516374
#
#
# At random state 9,the training accuracy is: 0.5665830704427692
# At random state 9,the testing accuracy is: 0.5474845476768175
#
#
# At random state 10,the training accuracy is: 0.5589063020969463
# At random state 10,the testing accuracy is: 0.5776982766329719
#
#
# At random state 11,the training accuracy is: 0.5653633790034582
# At random state 11,the testing accuracy is: 0.5521463806074917
#
#
# At random state 12,the training accuracy is: 0.5589968876948332
# At random state 12,the testing accuracy is: 0.5774915953151352
#
#
# At random state 13,the training accuracy is: 0.5638876208101682
# At random state 13,the testing accuracy is: 0.5582053465242991
#
#
# At random state 14,the training accuracy is: 0.5616351203504127
# At random state 14,the testing accuracy is: 0.5680578431592394
#
#
# At random state 15,the training accuracy is: 0.5604346836949988
# At random state 15,the testing accuracy is: 0.5706477110712838
#
#
# At random state 16,the training accuracy is: 0.5635510735322117
# At random state 16,the testing accuracy is: 0.5588461509833618
#
#
# At random state 17,the training accuracy is: 0.5630293253549652
# At random state 17,the testing accuracy is: 0.5619937526763017
#
#
# At random state 18,the training accuracy is: 0.5654244836090394
# At random state 18,the testing accuracy is: 0.5528316723016939
#
#
# At random state 19,the training accuracy is: 0.5653396366368211
# At random state 19,the testing accuracy is: 0.5529097297877714
#
#
# At random state 20,the training accuracy is: 0.5612675272737837
# At random state 20,the testing accuracy is: 0.5687111793995792
#
#
# At random state 21,the training accuracy is: 0.5635047655810812
# At random state 21,the testing accuracy is: 0.5601187504898937
#
#
# At random state 22,the training accuracy is: 0.5682018978456852
# At random state 22,the testing accuracy is: 0.5425122035130048
#
#
# At random state 23,the training accuracy is: 0.5631564234060962
# At random state 23,the testing accuracy is: 0.5610512251839612
#
#
# At random state 24,the training accuracy is: 0.5657163385563079
# At random state 24,the testing accuracy is: 0.5499936175081541
#
#
# At random state 25,the training accuracy is: 0.5636775765795918
# At random state 25,the testing accuracy is: 0.5591949809698936
#
#
# At random state 26,the training accuracy is: 0.5619721685101507
# At random state 26,the testing accuracy is: 0.565849910301863
#
#
# At random state 27,the training accuracy is: 0.5655138479680732
# At random state 27,the testing accuracy is: 0.5521231756936746
#
#
# At random state 28,the training accuracy is: 0.559137601152846
# At random state 28,the testing accuracy is: 0.577437512275239
#
#
# At random state 29,the training accuracy is: 0.5623562516537459
# At random state 29,the testing accuracy is: 0.5645450084070641
#
#
# At random state 30,the training accuracy is: 0.5648262412904823
# At random state 30,the testing accuracy is: 0.5547320202059904
#
#
# At random state 31,the training accuracy is: 0.562275919216794
# At random state 31,the testing accuracy is: 0.5646471816730161
#
#
# At random state 32,the training accuracy is: 0.5635080166277496
# At random state 32,the testing accuracy is: 0.5597937910897345
#
#
# At random state 33,the training accuracy is: 0.56336124698813
# At random state 33,the testing accuracy is: 0.5599933512348063
#
#
# At random state 34,the training accuracy is: 0.563537150991243
# At random state 34,the testing accuracy is: 0.5589990470520207
#
#
# At random state 35,the training accuracy is: 0.5621788428706848
# At random state 35,the testing accuracy is: 0.5648424878154956
#
#
# At random state 36,the training accuracy is: 0.5668484042584445
# At random state 36,the testing accuracy is: 0.5438785753746265
#
#
# At random state 37,the training accuracy is: 0.5675640338564132
# At random state 37,the testing accuracy is: 0.5416901362857766
#
#
# At random state 38,the training accuracy is: 0.565279070314975
# At random state 38,the testing accuracy is: 0.5521854444441567
#
#
# At random state 39,the training accuracy is: 0.5590809268904602
# At random state 39,the testing accuracy is: 0.5766771378374673
#
#
# At random state 40,the training accuracy is: 0.5621050035119853
# At random state 40,the testing accuracy is: 0.5646858604537157
#
#
# At random state 41,the training accuracy is: 0.569057693462846
# At random state 41,the testing accuracy is: 0.5383636123152393
#
#
# At random state 42,the training accuracy is: 0.5584574971799835
# At random state 42,the testing accuracy is: 0.5801166704683705
#
#
# At random state 43,the training accuracy is: 0.5624965901852099
# At random state 43,the testing accuracy is: 0.5630676500755728
#
#
# At random state 44,the training accuracy is: 0.561449277568735
# At random state 44,the testing accuracy is: 0.5682206348487092
#
#
# At random state 45,the training accuracy is: 0.5613785140253489
# At random state 45,the testing accuracy is: 0.5678630493608539
#
#
# At random state 46,the training accuracy is: 0.5670892135725675
# At random state 46,the testing accuracy is: 0.5444096313780991
#
#
# At random state 47,the training accuracy is: 0.5658687646815695
# At random state 47,the testing accuracy is: 0.5506154660705704
#
#
# At random state 48,the training accuracy is: 0.5629876832447628
# At random state 48,the testing accuracy is: 0.5618910304498024
#
#
# At random state 49,the training accuracy is: 0.5609910270027414
# At random state 49,the testing accuracy is: 0.5694100877314002
#
#
# At random state 50,the training accuracy is: 0.5623879378158663
# At random state 50,the testing accuracy is: 0.5645586032447345
#
#
# At random state 51,the training accuracy is: 0.5665113798079391
# At random state 51,the testing accuracy is: 0.5470048693392627
#
#
# At random state 52,the training accuracy is: 0.5629282681893515
# At random state 52,the testing accuracy is: 0.5620351595733128
#
#
# At random state 53,the training accuracy is: 0.5658853668097437
# At random state 53,the testing accuracy is: 0.5498556689661287
#
#
# At random state 54,the training accuracy is: 0.5587733018506792
# At random state 54,the testing accuracy is: 0.5765287275711124
#
#
# At random state 55,the training accuracy is: 0.5657802095071504
# At random state 55,the testing accuracy is: 0.5512705056314162
#
#
# At random state 56,the training accuracy is: 0.5693577936148944
# At random state 56,the testing accuracy is: 0.5379678661209476
#
#
# At random state 57,the training accuracy is: 0.564613874441112
# At random state 57,the testing accuracy is: 0.5551788212048658
#
#
# At random state 58,the training accuracy is: 0.562967075113273
# At random state 58,the testing accuracy is: 0.5619158575350939
#
#
# At random state 59,the training accuracy is: 0.5650012505811635
# At random state 59,the testing accuracy is: 0.5532938895121953
#
#
# At random state 60,the training accuracy is: 0.5603254964088439
# At random state 60,the testing accuracy is: 0.5722775805260573
#
#
# At random state 61,the training accuracy is: 0.5664813812297862
# At random state 61,the testing accuracy is: 0.5464234050694949
#
#
# At random state 62,the training accuracy is: 0.557046440484084
# At random state 62,the testing accuracy is: 0.5850853205862212
#
#
# At random state 63,the training accuracy is: 0.5590305253098545
# At random state 63,the testing accuracy is: 0.5785903530259204
#
#
# At random state 64,the training accuracy is: 0.5669152179892725
# At random state 64,the testing accuracy is: 0.5465061278355178
# At random state 65,the training accuracy is: 0.5627888251131742
# At random state 65,the testing accuracy is: 0.5626390308584629
#
#
# At random state 66,the training accuracy is: 0.564757424736164
# At random state 66,the testing accuracy is: 0.554963018106359
#
#
# At random state 67,the training accuracy is: 0.5619930037126871
# At random state 67,the testing accuracy is: 0.5658726071358084
#
#
# At random state 68,the training accuracy is: 0.5620257548567145
# At random state 68,the testing accuracy is: 0.5656861144315584
#
#
# At random state 69,the training accuracy is: 0.5631624759965632
# At random state 69,the testing accuracy is: 0.5608813655434846
#
#
# At random state 70,the training accuracy is: 0.561576315885921
# At random state 70,the testing accuracy is: 0.5670465880681919
#
#
# At random state 71,the training accuracy is: 0.5615185370974629
# At random state 71,the testing accuracy is: 0.5681573986449442
#
#
# At random state 72,the training accuracy is: 0.5578535760933457
# At random state 72,the testing accuracy is: 0.5826133630944956
#
#
# At random state 73,the training accuracy is: 0.5666476091077798
# At random state 73,the testing accuracy is: 0.5454693958784947
#
#
# At random state 74,the training accuracy is: 0.568415080972933
# At random state 74,the testing accuracy is: 0.5390425002924715
#
#
# At random state 75,the training accuracy is: 0.5613551400235908
# At random state 75,the testing accuracy is: 0.5681571686245528
#
#
# At random state 76,the training accuracy is: 0.5583152394206622
# At random state 76,the testing accuracy is: 0.5809857771691012
#
#
# At random state 77,the training accuracy is: 0.5632206918515261
# At random state 77,the testing accuracy is: 0.5609676816042752
#
#
# At random state 78,the training accuracy is: 0.5674989544269503
# At random state 78,the testing accuracy is: 0.5441898699547406
#
#
# At random state 79,the training accuracy is: 0.5613197246881134
# At random state 79,the testing accuracy is: 0.567431539852679
#
#
# At random state 80,the training accuracy is: 0.5603263018915415
# At random state 80,the testing accuracy is: 0.5727427970049499
#
#
# At random state 81,the training accuracy is: 0.5623820453661975
# At random state 81,the testing accuracy is: 0.5649117296372173
#
#
# At random state 82,the training accuracy is: 0.5636709801799471
# At random state 82,the testing accuracy is: 0.5591048600952641
#
#
# At random state 83,the training accuracy is: 0.5642556530654312
# At random state 83,the testing accuracy is: 0.5558294949370326
#
#
# At random state 84,the training accuracy is: 0.5616754150596822
# At random state 84,the testing accuracy is: 0.5653676408519661
#
#
# At random state 85,the training accuracy is: 0.562516715868404
# At random state 85,the testing accuracy is: 0.5633644062460574
#
#
# At random state 86,the training accuracy is: 0.5635184926849401
# At random state 86,the testing accuracy is: 0.5596870412722599
#
#
# At random state 87,the training accuracy is: 0.5675552718583419
# At random state 87,the testing accuracy is: 0.5419321052598286
#
#
# At random state 88,the training accuracy is: 0.5627346668114989
# At random state 88,the testing accuracy is: 0.5625089599437051
#
#
# At random state 89,the training accuracy is: 0.5577038601818924
# At random state 89,the testing accuracy is: 0.5833973200769917
#
#
# At random state 90,the training accuracy is: 0.5695612277384339
# At random state 90,the testing accuracy is: 0.532555172819634
#
#
# At random state 91,the training accuracy is: 0.565059553027239
# At random state 91,the testing accuracy is: 0.5534201325092234
#
#
# At random state 92,the training accuracy is: 0.5603419774650396
# At random state 92,the testing accuracy is: 0.571449048615358
#
#
# At random state 93,the training accuracy is: 0.5634597391449478
# At random state 93,the testing accuracy is: 0.560325391890903
#
#
# At random state 94,the training accuracy is: 0.5626046726218782
# At random state 94,the testing accuracy is: 0.5619134523019891
#
#
# At random state 95,the training accuracy is: 0.5628167721387745
# At random state 95,the testing accuracy is: 0.5630592106547687
#
#
# At random state 96,the training accuracy is: 0.5651779080376909
# At random state 96,the testing accuracy is: 0.5505774949983435
#
#
# At random state 97,the training accuracy is: 0.5625584899177165
# At random state 97,the testing accuracy is: 0.5623351582256095
#
#
# At random state 98,the training accuracy is: 0.5667714907649921
# At random state 98,the testing accuracy is: 0.5454018256243749
#
#
# At random state 99,the training accuracy is: 0.560118224957219
# At random state 99,the testing accuracy is: 0.571584765423109

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=18)

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.48048225173650616
# 0.2652399426235178
# 0.18555517782720132

# %%
sv=SVR(kernel='linear')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
ab=AdaBoostRegressor()

model=[lr,sv,dt,rf,ab]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    test_score=r2_score(y_test,pred_test)
    print('Accuracy of', m )
    print('Training Score', train_score)
    print('Testing Score', test_score)
    print('\n')
# Out:
# Accuracy of LinearRegression()
# Training Score 0.5654244836090394
# Testing Score 0.5528316723016939
#
#
# Accuracy of SVR(kernel='linear')
# Training Score 0.48048225173650616
# Testing Score 0.46287763829394657
#
#
# Accuracy of DecisionTreeRegressor()
# Training Score 1.0
# Testing Score 0.16676247799924415
#
#
# Accuracy of RandomForestRegressor()
# Training Score 0.9368503514226386
# Testing Score 0.5427555468298242
#
#
# Accuracy of AdaBoostRegressor()
# Training Score 0.5263453061829697
# Testing Score 0.5036919696116937

# %% [markdown]
# Found LinearRegression is the best model to fit

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

model=(lr,sv,dt,rf,ab)
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Mean Accuracy of ',m)
    print(score.mean())
    print('\n')
# Out:
# Mean Accuracy of  LinearRegression()
# 0.5606417806465656
#
#
# Mean Accuracy of  SVR(kernel='linear')
# 0.4756642741834042
#
#
# Mean Accuracy of  DecisionTreeRegressor()
# 0.16274395705010597
#
#
# Mean Accuracy of  RandomForestRegressor()
# 0.5455918461393885
#
#
# Mean Accuracy of  AdaBoostRegressor()
# 0.47337965076831556

# %% [markdown]
# # Normalization and Hypertuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.5528395755010098

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5606427023493519

# %% [markdown]
# Found that there is not such difference after tuning

# %% [markdown]
# # Saving the Final Model

# %%
final_mod=LinearRegression(copy_X=True, fit_intercept= True, n_jobs=None, normalize=False)
final_mod.fit(x_train,y_train)
pred_final=final_mod.predict(x_test)
rfs=r2_score(y_test,pred_final)
print('R2 Score', rfs*100)

rf_score=cross_val_score(final_mod,x,y,cv=5)
rfc=rf_score.mean()
print('Cross Val score', rfc*100)
# Out:
# R2 Score 55.2831672301694
# Cross Val score 56.06417806465656

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_final,color='g')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Sales',fontsize=14)
plt.ylabel('Predicted Sales',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
import joblib
joblib.dump(Finalmod,'BigMart_sales.obj')
# Out:
# ['BigMart_sales.obj']

# %%
load_model=joblib.load('BigMart_sales.obj')

# %%
x = df_test.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier'])

# %%
test_pred=load_model.predict(x)

# %%
pred_sales=pd.DataFrame(data=test_pred)

# %%
df_predict=df_test.join(pred_sales)
df_predict.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0            Food    20.750000         0.086976         13  107.8622
# 1            Food     8.300000         0.196030          4   87.3198
# 2  Non Consumable    14.600000         0.315555         11  241.7538
# 3            Food     7.315000         0.124050         13  155.0340
# 4            Food    12.695633         0.344383          4  234.2300
#
#   Outlet_Identifier  Outlet_Establishment_Year  Outlet_Years  \
# 0            OUT049                        -14            14
# 1            OUT017                         -6             6
# 2            OUT010                        -15            15
# 3            OUT017                         -6             6
# 4            OUT027                        -28            28
#
#    Item_Fat_Content_0  Item_Fat_Content_1  ...  Outlet_Location_Type_1  \
# 0                   1                   0  ...                       0
# 1                   0                   0  ...                       1
# 2                   0                   1  ...                       0
# 3                   1                   0  ...                       1
# 4                   0                   0  ...                       0
#
#    Outlet_Location_Type_2  Outlet_Type_0  Outlet_Type_1  Outlet_Type_2  \
# 0                       0              0              1              0
# 1                       0              0              1              0
# 2                       1              1              0              0
# 3                       0              0              1              0
# 4                       1              0              0              0
#
#    Outlet_Type_3  New_Item_Type_0  New_Item_Type_1  New_Item_Type_2  \
# 0              0                0                1                0
# 1              0                0                1                0
# 2              0                0                0                1
# 3              0                0                1                0
# 4              1                0                1                0
#
#              0
# 0  1853.534772
# 1  1622.134406
# 2  1887.664430
# 3  2630.792410
# 4  5147.608303
#
# [5 rows x 25 columns]
